# %%
import math

class figuras():
    def area(self) -> float:
        pass


class triangulo(figuras):

    def __init__(self, base: float, altura: float):
        self.__base = base
        self.__altura = altura

    def area(self) -> float:
        return (self.__base * self.__altura) / 2


class circulo(figuras):

    def __init__(self, radio: float):
        self.__radio = radio

    def area(self) -> float:
        return math.pi*(self.__radio**2)


tfiguras = [triangulo(3, 4), circulo(6)]
for f in tfiguras:
    print(f"Área= {f.area():.3f}")
# Out:
# Área= 6.000
# Área= 113.097
